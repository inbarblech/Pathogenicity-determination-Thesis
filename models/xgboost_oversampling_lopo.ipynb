# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, matthews_corrcoef, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
protein = "WFS1" # GJB2
filename = f'C:\\Users\\InbarBlech\\PycharmProjects\\Thesis\\gene_specific_df\\{protein}_with_position.csv'
data = pd.read_csv(f"{filename}")
data.head(10)
dot_index = filename.index('_')
gene = filename[:dot_index]
if gene == "combined" or gene == "combined_with_source":
    gene = "7 genes"
if gene == "features":
    gene = "190 genes"

data
# Out:
#      gene variant pathogenicity uniprot_id  stability_WT  stability_MUT  \
# 0    WFS1     T5A        benign     O76024       406.243        406.410
# 1    WFS1     P7A        benign     O76024       406.550        406.820
# 2    WFS1     P7Q        benign     O76024       406.550        406.421
# 3    WFS1    P16L        benign     O76024       405.800        406.781
# 4    WFS1    P17L        benign     O76024       405.187        405.847
# ..    ...     ...           ...        ...           ...            ...
# 305  WFS1    Q14R        benign        NaN       405.740        405.538
# 306  WFS1   L499F        benign        NaN       406.155        405.569
# 307  WFS1   D866N        benign        NaN       403.125        405.666
# 308  WFS1    G76V        benign        NaN       406.550        406.536
# 309  WFS1   V779M        benign        NaN       404.550        405.845
#
#      blosum  hydrophobicity_WT  hydrophobicity_MUT  volume_WT  ...  oda_MUT  \
# 0         0               -0.7                 1.8      116.1  ...    -0.65
# 1        -1               -1.6                 1.8      112.7  ...    -3.77
# 2        -1               -1.6                -3.5      112.7  ...    -0.57
# 3        -3               -1.6                 3.8      112.7  ...    -8.98
# 4        -3               -1.6                 3.8      112.7  ...    -7.48
# ..      ...                ...                 ...        ...  ...      ...
# 305       1               -3.5                -4.5      143.8  ...   -10.21
# 306       0                3.8                 2.8      166.7  ...  -114.10
# 307       1               -3.5                -3.5      111.1  ...   -92.65
# 308      -3               -0.4                 4.2       60.1  ...    -1.63
# 309       1                4.2                 1.9      140.0  ...     0.00
#
#      sasa_WT sasa_MUT    RSA_WT   RSA_MUT  oda_delta sasa_delta   pssm  \
# 0     144.59   110.51  0.887055  0.913306      -1.27     -34.08  3.675
# 1     129.82   103.89  0.842987  0.858595       0.79     -25.93  4.586
# 2     129.82   171.78  0.842987  0.802710       3.99      41.96  4.586
# 3     118.89   163.92  0.772013  0.858220       0.81      45.03  4.641
# 4     127.58   131.68  0.828442  0.689424      -1.29       4.10  3.746
# ..       ...      ...       ...       ...        ...        ...    ...
# 305   170.60   184.05  0.797196  0.694528      -0.23      13.45  5.242
# 306    44.63    53.58  0.233665  0.235000      -4.40       8.95  4.098
# 307   101.80    94.71  0.544385  0.506471     -13.02      -7.09  6.115
# 308    73.47   133.73  0.757423  0.810485      -1.64      60.26  3.942
# 309     0.00     0.00  0.000000  0.000000       0.00       0.00  4.828
#
#      entropy  position
# 0      3.042         5
# 1      2.483         7
# 2      2.483         7
# 3      2.163        16
# 4      2.255        17
# ..       ...       ...
# 305    2.839        14
# 306    0.870       499
# 307    1.105       866
# 308    2.494        76
# 309    1.337       779
#
# [310 rows x 32 columns]

# %%
data = pd.get_dummies(data, columns=["secondary_structure"])

mapping = {"benign": 0, "pathogenic": 1}
data["pathogenicity"] = data["pathogenicity"].map(mapping)

data = data.drop(
    labels=["uniprot_id", "stability_WT", "stability_MUT", "hydrophobicity_WT", "hydrophobicity_MUT", "volume_WT",
            "volume_MUT", "sequence_length", "oda_MUT", "oda_WT", "sasa_WT", "sasa_MUT", "RSA_MUT", "variant", "gene",
            "protein_contain_transmembrane", "is_residue_transmembranal", "aa_WT", "aa_MUT"], axis=1, inplace=False)

data
# Out:
#      pathogenicity  blosum  plddt_residue  stability_delta  \
# 0                0       0          36.76            0.167
# 1                0      -1          37.60            0.270
# 2                0      -1          37.60           -0.129
# 3                0      -3          33.77            0.981
# 4                0      -3          34.09            0.660
# ..             ...     ...            ...              ...
# 305              0       1          33.40           -0.202
# 306              0       0          82.30           -0.586
# 307              0       1          66.68            2.541
# 308              0      -3          25.97           -0.014
# 309              0       1          90.56            1.295
#
#      hydrophobicity_delta  volume_delta    RSA_WT  oda_delta  sasa_delta  \
# 0                     2.5         -27.5  0.887055      -1.27      -34.08
# 1                     3.4         -24.1  0.842987       0.79      -25.93
# 2                    -1.9          31.1  0.842987       3.99       41.96
# 3                     5.4          54.0  0.772013       0.81       45.03
# 4                     5.4          54.0  0.828442      -1.29        4.10
# ..                    ...           ...       ...        ...         ...
# 305                  -1.0          29.6  0.797196      -0.23       13.45
# 306                  -1.0          23.2  0.233665      -4.40        8.95
# 307                   0.0           3.0  0.544385     -13.02       -7.09
# 308                   4.6          79.9  0.757423      -1.64       60.26
# 309                  -2.3          22.9  0.000000       0.00        0.00
#
#       pssm  entropy  position  secondary_structure_Loop
# 0    3.675    3.042         5                      True
# 1    4.586    2.483         7                      True
# 2    4.586    2.483         7                      True
# 3    4.641    2.163        16                      True
# 4    3.746    2.255        17                      True
# ..     ...      ...       ...                       ...
# 305  5.242    2.839        14                      True
# 306  4.098    0.870       499                      True
# 307  6.115    1.105       866                      True
# 308  3.942    2.494        76                      True
# 309  4.828    1.337       779                      True
#
# [310 rows x 13 columns]

# %%
structural_features = ["oda_delta", "stability_delta", "secondary_structure_Beta strand", "secondary_structure_Helix", "secondary_structure_Loop", "sasa_delta", "RSA_WT"]
# Drop structural features
data = data.drop(labels=["stability_delta"], axis=1, inplace=False)

# %%
# Create list of all positions.
positions = data["position"].unique()
tps = []
fps = []
fns = []
tns = []
errors = []
mistakes = 0

counter = 0

for pos in positions:
    counter += 1
    print(f"Position: {pos} ({counter}/{len(positions)})")
    # Create train and test sets.
    train = data[data["position"] != pos]
    test = data[data["position"] == pos]

    X_test = test.drop(labels=["pathogenicity", "position"], axis=1, inplace=False)
    y_test = test["pathogenicity"]

    # Oversamole the train set using SMOTE.
    X_train = train.drop(labels=["pathogenicity", "position"], axis=1, inplace=False)
    y_train = train["pathogenicity"]
    oversample = SMOTE(sampling_strategy='minority', random_state=42)
    X_train_resampled, y_train_resampled = oversample.fit_resample(X_train, y_train)
    # class_distribution = y_train_resampled.value_counts()
    # print(f"Training set: (SMOTE)\n{class_distribution}")

    xgb_classifier = xgb.XGBClassifier(learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42)
    xgb_classifier.fit(X_train_resampled, y_train_resampled)  # Fit the model with the resampled data
    y_pred = xgb_classifier.predict(X_test)

    tp = sum((y_test == 1) & (y_pred == 1))
    fp = sum((y_test == 0) & (y_pred == 1))
    fn = sum((y_test == 1) & (y_pred == 0))
    tn = sum((y_test == 0) & (y_pred == 0))

    print(f"TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}")

    tps.append(tp)
    fps.append(fp)
    fns.append(fn)
    tns.append(tn)

    print(f"tps: {sum(tps)}, fps: {sum(fps)}, fns: {sum(fns)}, tns: {sum(tns)}")

    print(f"Prediction: {y_pred}. Reality: {y_test.values}")
    # # print error if at least one prediction is wrong
    # if not np.array_equal(y_pred, y_test.values):
    #     print(f"Classification is wrong for position {pos}!")
    #     for i in range(len(y_pred)):
    #         if y_pred[i] != y_test.values[i]:
    #             mistakes+=1
    #             print(f"Predicted: {y_pred[i]}, reality: {y_test.values[i]}")

# Calculate MCC
TP = sum(tps)
FP = sum(fps)
FN = sum(fns)
TN = sum(tns)
mcc = (TP * TN - FP * FN) / np.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))

print(f"TP: {sum(tps)}, FP: {sum(fps)}, TN: {sum(fns)}, FN: {sum(tns)}")

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision = TP / (TP + FP)
accuracy = (TP + TN) / (TP + TN + FP + FN)
print(f"Results for {gene}:")
print(f"Sensitivity (Recall): {sensitivity}")
print(f"Specificity: {specificity}")
print(f"Precision: {precision}")
print(f"MCC for {gene}: {mcc}")
print(f"Accuracy: {accuracy}")
# Out:
# Position: 5 (1/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 1
# Prediction: [0]. Reality: [0]
# Position: 7 (2/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 3
# Prediction: [0 0]. Reality: [0 0]
# Position: 16 (3/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 4
# Prediction: [0]. Reality: [0]
# Position: 17 (4/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 6
# Prediction: [0 0]. Reality: [0 0]
# Position: 19 (5/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 7
# Prediction: [0]. Reality: [0]
# Position: 23 (6/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 8
# Prediction: [0]. Reality: [0]
# Position: 40 (7/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 9
# Prediction: [0]. Reality: [0]
# Position: 41 (8/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 10
# Prediction: [0]. Reality: [0]
# Position: 44 (9/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 12
# Prediction: [0 0]. Reality: [0 0]
# Position: 47 (10/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 13
# Prediction: [0]. Reality: [0]
# Position: 49 (11/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 14
# Prediction: [0]. Reality: [0]
# Position: 51 (12/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 15
# Prediction: [0]. Reality: [0]
# Position: 53 (13/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 16
# Prediction: [0]. Reality: [0]
# Position: 54 (14/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 17
# Prediction: [0]. Reality: [0]
# Position: 57 (15/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 19
# Prediction: [0 0]. Reality: [0 0]
# Position: 64 (16/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 20
# Prediction: [0]. Reality: [0]
# Position: 65 (17/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 21
# Prediction: [0]. Reality: [0]
# Position: 66 (18/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 22
# Prediction: [0]. Reality: [0]
# Position: 67 (19/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 23
# Prediction: [0]. Reality: [0]
# Position: 71 (20/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 24
# Prediction: [0]. Reality: [0]
# Position: 76 (21/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 26
# Prediction: [0 0]. Reality: [0 0]
# Position: 81 (22/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 27
# Prediction: [0]. Reality: [0]
# Position: 84 (23/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 28
# Prediction: [0]. Reality: [0]
# Position: 86 (24/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 29
# Prediction: [0]. Reality: [0]
# Position: 91 (25/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 30
# Prediction: [0]. Reality: [0]
# Position: 106 (26/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 0, fns: 0, tns: 31
# Prediction: [0]. Reality: [0]
# Position: 114 (27/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 1, fns: 0, tns: 31
# Prediction: [1]. Reality: [0]
# Position: 115 (28/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 1, fns: 0, tns: 33
# Prediction: [0 0]. Reality: [0 0]
# Position: 116 (29/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 1, fns: 0, tns: 35
# Prediction: [0 0]. Reality: [0 0]
# Position: 117 (30/245)
# TP: 0, FP: 0, TN: 5, FN: 0
# tps: 0, fps: 1, fns: 0, tns: 40
# Prediction: [0 0 0 0 0]. Reality: [0 0 0 0 0]
# Position: 118 (31/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 2, fns: 0, tns: 40
# Prediction: [1]. Reality: [0]
# Position: 119 (32/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 2, fns: 0, tns: 41
# Prediction: [0]. Reality: [0]
# Position: 120 (33/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 2, fns: 0, tns: 42
# Prediction: [0]. Reality: [0]
# Position: 122 (34/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 3, fns: 0, tns: 42
# Prediction: [1]. Reality: [0]
# Position: 123 (35/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 3, fns: 0, tns: 43
# Prediction: [0]. Reality: [0]
# Position: 124 (36/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 4, fns: 0, tns: 43
# Prediction: [1]. Reality: [0]
# Position: 130 (37/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 5, fns: 0, tns: 43
# Prediction: [1]. Reality: [0]
# Position: 131 (38/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 5, fns: 0, tns: 45
# Prediction: [0 0]. Reality: [0 0]
# Position: 141 (39/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 6, fns: 0, tns: 45
# Prediction: [1]. Reality: [0]
# Position: 142 (40/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 6, fns: 0, tns: 46
# Prediction: [0]. Reality: [0]
# Position: 144 (41/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 7, fns: 0, tns: 46
# Prediction: [1]. Reality: [0]
# Position: 145 (42/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 8, fns: 0, tns: 46
# Prediction: [1]. Reality: [0]
# Position: 146 (43/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 46
# Prediction: [1]. Reality: [0]
# Position: 147 (44/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 47
# Prediction: [0]. Reality: [0]
# Position: 150 (45/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 48
# Prediction: [0]. Reality: [0]
# Position: 151 (46/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 49
# Prediction: [0]. Reality: [0]
# Position: 153 (47/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 50
# Prediction: [0]. Reality: [0]
# Position: 161 (48/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 52
# Prediction: [0 0]. Reality: [0 0]
# Position: 210 (49/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 53
# Prediction: [0]. Reality: [0]
# Position: 213 (50/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 54
# Prediction: [0]. Reality: [0]
# Position: 214 (51/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 55
# Prediction: [0]. Reality: [0]
# Position: 223 (52/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 9, fns: 0, tns: 56
# Prediction: [0]. Reality: [0]
# Position: 245 (53/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 10, fns: 0, tns: 56
# Prediction: [1]. Reality: [0]
# Position: 250 (54/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 10, fns: 0, tns: 57
# Prediction: [0]. Reality: [0]
# Position: 258 (55/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 10, fns: 0, tns: 58
# Prediction: [0]. Reality: [0]
# Position: 264 (56/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 10, fns: 0, tns: 59
# Prediction: [0]. Reality: [0]
# Position: 306 (57/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 0, fps: 10, fns: 0, tns: 61
# Prediction: [0 0]. Reality: [0 0]
# Position: 312 (58/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 11, fns: 0, tns: 61
# Prediction: [1]. Reality: [0]
# Position: 315 (59/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 11, fns: 0, tns: 62
# Prediction: [0]. Reality: [0]
# Position: 333 (60/245)
# TP: 0, FP: 3, TN: 0, FN: 0
# tps: 0, fps: 14, fns: 0, tns: 62
# Prediction: [1 1 1]. Reality: [0 0 0]
# Position: 406 (61/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 14, fns: 0, tns: 63
# Prediction: [0]. Reality: [0]
# Position: 413 (62/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 14, fns: 0, tns: 64
# Prediction: [0]. Reality: [0]
# Position: 421 (63/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 14, fns: 0, tns: 65
# Prediction: [0]. Reality: [0]
# Position: 422 (64/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 65
# Prediction: [1]. Reality: [0]
# Position: 436 (65/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 66
# Prediction: [0]. Reality: [0]
# Position: 477 (66/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 67
# Prediction: [0]. Reality: [0]
# Position: 483 (67/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 68
# Prediction: [0]. Reality: [0]
# Position: 484 (68/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 69
# Prediction: [0]. Reality: [0]
# Position: 489 (69/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 70
# Prediction: [0]. Reality: [0]
# Position: 491 (70/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 71
# Prediction: [0]. Reality: [0]
# Position: 498 (71/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 72
# Prediction: [0]. Reality: [0]
# Position: 501 (72/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 73
# Prediction: [0]. Reality: [0]
# Position: 503 (73/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 0, fps: 15, fns: 0, tns: 74
# Prediction: [0]. Reality: [0]
# Position: 506 (74/245)
# TP: 1, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 15, fns: 0, tns: 75
# Prediction: [0 1]. Reality: [0 1]
# Position: 509 (75/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 15, fns: 0, tns: 76
# Prediction: [0]. Reality: [0]
# Position: 514 (76/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 15, fns: 0, tns: 77
# Prediction: [0]. Reality: [0]
# Position: 520 (77/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 15, fns: 0, tns: 78
# Prediction: [0]. Reality: [0]
# Position: 564 (78/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 1, fps: 16, fns: 0, tns: 78
# Prediction: [1]. Reality: [0]
# Position: 576 (79/245)
# TP: 0, FP: 2, TN: 0, FN: 0
# tps: 1, fps: 18, fns: 0, tns: 78
# Prediction: [1 1]. Reality: [0 0]
# Position: 590 (80/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 1, fps: 18, fns: 0, tns: 80
# Prediction: [0 0]. Reality: [0 0]
# Position: 601 (81/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 18, fns: 0, tns: 81
# Prediction: [0]. Reality: [0]
# Position: 602 (82/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 1, fps: 18, fns: 0, tns: 83
# Prediction: [0 0]. Reality: [0 0]
# Position: 606 (83/245)
# TP: 0, FP: 0, TN: 1, FN: 1
# tps: 1, fps: 18, fns: 1, tns: 84
# Prediction: [0 0]. Reality: [0 1]
# Position: 620 (84/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 18, fns: 1, tns: 85
# Prediction: [0]. Reality: [0]
# Position: 624 (85/245)
# TP: 0, FP: 0, TN: 1, FN: 1
# tps: 1, fps: 18, fns: 2, tns: 86
# Prediction: [0 0]. Reality: [0 1]
# Position: 632 (86/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 18, fns: 2, tns: 87
# Prediction: [0]. Reality: [0]
# Position: 671 (87/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 1, fps: 18, fns: 2, tns: 89
# Prediction: [0 0]. Reality: [0 0]
# Position: 692 (88/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 1, fps: 19, fns: 2, tns: 89
# Prediction: [1]. Reality: [0]
# Position: 725 (89/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 19, fns: 2, tns: 90
# Prediction: [0]. Reality: [0]
# Position: 728 (90/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 1, fps: 20, fns: 2, tns: 90
# Prediction: [1]. Reality: [0]
# Position: 741 (91/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 20, fns: 2, tns: 91
# Prediction: [0]. Reality: [0]
# Position: 743 (92/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 91
# Prediction: [1]. Reality: [0]
# Position: 786 (93/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 93
# Prediction: [0 0]. Reality: [0 0]
# Position: 787 (94/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 94
# Prediction: [0]. Reality: [0]
# Position: 788 (95/245)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 96
# Prediction: [0 0]. Reality: [0 0]
# Position: 789 (96/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 97
# Prediction: [0]. Reality: [0]
# Position: 792 (97/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 98
# Prediction: [0]. Reality: [0]
# Position: 816 (98/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 99
# Prediction: [0]. Reality: [0]
# Position: 822 (99/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 100
# Prediction: [0]. Reality: [0]
# Position: 857 (100/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 101
# Prediction: [0]. Reality: [0]
# Position: 875 (101/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 1, fps: 21, fns: 2, tns: 102
# Prediction: [0]. Reality: [0]
# Position: 676 (102/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 1, fps: 21, fns: 3, tns: 102
# Prediction: [0]. Reality: [1]
# Position: 685 (103/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 2, fps: 21, fns: 3, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 518 (104/245)
# TP: 2, FP: 1, TN: 0, FN: 0
# tps: 4, fps: 22, fns: 3, tns: 102
# Prediction: [1 1 1]. Reality: [1 1 0]
# Position: 200 (105/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 5, fps: 22, fns: 3, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 308 (106/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 6, fps: 22, fns: 3, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 296 (107/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 7, fps: 22, fns: 3, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 236 (108/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 7, fps: 22, fns: 4, tns: 102
# Prediction: [0]. Reality: [1]
# Position: 432 (109/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 9, fps: 22, fns: 4, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 859 (110/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 11, fps: 22, fns: 4, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 832 (111/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 12, fps: 22, fns: 4, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 844 (112/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 13, fps: 22, fns: 4, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 684 (113/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 15, fps: 22, fns: 4, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 292 (114/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 17, fps: 22, fns: 4, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 494 (115/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 18, fps: 22, fns: 4, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 504 (116/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 20, fps: 22, fns: 4, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 314 (117/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 21, fps: 22, fns: 4, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 58 (118/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 21, fps: 22, fns: 5, tns: 102
# Prediction: [0]. Reality: [1]
# Position: 702 (119/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 23, fps: 22, fns: 5, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 584 (120/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 24, fps: 22, fns: 5, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 707 (121/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 25, fps: 22, fns: 5, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 807 (122/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 26, fps: 22, fns: 5, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 736 (123/245)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 29, fps: 22, fns: 5, tns: 102
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 337 (124/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 30, fps: 22, fns: 5, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 228 (125/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 30, fps: 22, fns: 6, tns: 102
# Prediction: [0]. Reality: [1]
# Position: 188 (126/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 31, fps: 22, fns: 6, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 674 (127/245)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 34, fps: 22, fns: 6, tns: 102
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 770 (128/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 35, fps: 22, fns: 6, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 350 (129/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 37, fps: 22, fns: 6, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 543 (130/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 38, fps: 22, fns: 6, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 634 (131/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 39, fps: 22, fns: 6, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 156 (132/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 40, fps: 22, fns: 6, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 443 (133/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 42, fps: 22, fns: 6, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 723 (134/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 43, fps: 22, fns: 6, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 682 (135/245)
# TP: 0, FP: 0, TN: 0, FN: 2
# tps: 43, fps: 22, fns: 8, tns: 102
# Prediction: [0 0]. Reality: [1 1]
# Position: 439 (136/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 44, fps: 22, fns: 8, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 860 (137/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 44, fps: 22, fns: 9, tns: 102
# Prediction: [0]. Reality: [1]
# Position: 461 (138/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 44, fps: 22, fns: 10, tns: 102
# Prediction: [0]. Reality: [1]
# Position: 732 (139/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 45, fps: 22, fns: 10, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 780 (140/245)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 48, fps: 22, fns: 10, tns: 102
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 874 (141/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 49, fps: 22, fns: 10, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 383 (142/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 50, fps: 22, fns: 10, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 845 (143/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 51, fps: 22, fns: 10, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 690 (144/245)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 54, fps: 22, fns: 10, tns: 102
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 629 (145/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 55, fps: 22, fns: 10, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 714 (146/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 57, fps: 22, fns: 10, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 834 (147/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 58, fps: 22, fns: 10, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 356 (148/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 59, fps: 22, fns: 10, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 696 (149/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 60, fps: 22, fns: 10, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 457 (150/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 62, fps: 22, fns: 10, tns: 102
# Prediction: [1 1]. Reality: [1 1]
# Position: 288 (151/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 62, fps: 22, fns: 11, tns: 102
# Prediction: [0]. Reality: [1]
# Position: 699 (152/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 63, fps: 22, fns: 11, tns: 102
# Prediction: [1]. Reality: [1]
# Position: 437 (153/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 63, fps: 22, fns: 12, tns: 102
# Prediction: [0]. Reality: [1]
# Position: 871 (154/245)
# TP: 1, FP: 0, TN: 1, FN: 0
# tps: 64, fps: 22, fns: 12, tns: 103
# Prediction: [1 0]. Reality: [1 0]
# Position: 557 (155/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 64, fps: 22, fns: 13, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 669 (156/245)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 67, fps: 22, fns: 13, tns: 103
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 665 (157/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 68, fps: 22, fns: 13, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 830 (158/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 69, fps: 22, fns: 13, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 631 (159/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 70, fps: 22, fns: 13, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 402 (160/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 71, fps: 22, fns: 13, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 126 (161/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 72, fps: 22, fns: 13, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 766 (162/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 73, fps: 22, fns: 13, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 427 (163/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 75, fps: 22, fns: 13, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 861 (164/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 76, fps: 22, fns: 13, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 700 (165/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 77, fps: 22, fns: 13, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 793 (166/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 77, fps: 22, fns: 14, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 888 (167/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 77, fps: 22, fns: 15, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 540 (168/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 78, fps: 22, fns: 15, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 864 (169/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 80, fps: 22, fns: 15, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 346 (170/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 81, fps: 22, fns: 15, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 248 (171/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 82, fps: 22, fns: 15, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 695 (172/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 83, fps: 22, fns: 15, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 843 (173/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 84, fps: 22, fns: 15, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 459 (174/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 85, fps: 22, fns: 15, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 349 (175/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 86, fps: 22, fns: 15, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 724 (176/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 87, fps: 22, fns: 15, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 831 (177/245)
# TP: 2, FP: 0, TN: 0, FN: 1
# tps: 89, fps: 22, fns: 16, tns: 103
# Prediction: [0 1 1]. Reality: [1 1 1]
# Position: 797 (178/245)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 92, fps: 22, fns: 16, tns: 103
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 708 (179/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 93, fps: 22, fns: 16, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 428 (180/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 94, fps: 22, fns: 16, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 505 (181/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 96, fps: 22, fns: 16, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 375 (182/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 98, fps: 22, fns: 16, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 729 (183/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 99, fps: 22, fns: 16, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 528 (184/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 101, fps: 22, fns: 16, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 705 (185/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 102, fps: 22, fns: 16, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 607 (186/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 103, fps: 22, fns: 16, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 158 (187/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 103, fps: 22, fns: 17, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 592 (188/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 104, fps: 22, fns: 17, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 320 (189/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 105, fps: 22, fns: 17, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 110 (190/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 106, fps: 22, fns: 17, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 683 (191/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 107, fps: 22, fns: 17, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 171 (192/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 107, fps: 22, fns: 18, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 611 (193/245)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 108, fps: 23, fns: 18, tns: 103
# Prediction: [1 1]. Reality: [1 0]
# Position: 430 (194/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 110, fps: 23, fns: 18, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 771 (195/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 111, fps: 23, fns: 18, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 559 (196/245)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 112, fps: 24, fns: 18, tns: 103
# Prediction: [1 1]. Reality: [1 0]
# Position: 232 (197/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 113, fps: 24, fns: 18, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 703 (198/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 113, fps: 24, fns: 19, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 639 (199/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 114, fps: 24, fns: 19, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 709 (200/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 116, fps: 24, fns: 19, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 650 (201/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 117, fps: 24, fns: 19, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 177 (202/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 118, fps: 24, fns: 19, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 211 (203/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 118, fps: 24, fns: 20, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 303 (204/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 119, fps: 24, fns: 20, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 838 (205/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 120, fps: 24, fns: 20, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 678 (206/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 122, fps: 24, fns: 20, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 716 (207/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 123, fps: 24, fns: 20, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 761 (208/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 123, fps: 24, fns: 21, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 616 (209/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 123, fps: 24, fns: 22, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 672 (210/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 124, fps: 24, fns: 22, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 323 (211/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 125, fps: 24, fns: 22, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 107 (212/245)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 127, fps: 24, fns: 22, tns: 103
# Prediction: [1 1]. Reality: [1 1]
# Position: 382 (213/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 128, fps: 24, fns: 22, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 546 (214/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 129, fps: 24, fns: 22, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 661 (215/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 130, fps: 24, fns: 22, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 511 (216/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 131, fps: 24, fns: 22, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 779 (217/245)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 132, fps: 25, fns: 22, tns: 103
# Prediction: [1 1]. Reality: [1 0]
# Position: 757 (218/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 132, fps: 25, fns: 23, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 321 (219/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 133, fps: 25, fns: 23, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 742 (220/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 134, fps: 25, fns: 23, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 836 (221/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 135, fps: 25, fns: 23, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 664 (222/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 136, fps: 25, fns: 23, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 545 (223/245)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 136, fps: 25, fns: 24, tns: 103
# Prediction: [0]. Reality: [1]
# Position: 202 (224/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 137, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 508 (225/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 138, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 677 (226/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 139, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 133 (227/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 140, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 809 (228/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 141, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 446 (229/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 142, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 462 (230/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 143, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 721 (231/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 144, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 329 (232/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 145, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 655 (233/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 146, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 806 (234/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 147, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 868 (235/245)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 148, fps: 25, fns: 24, tns: 103
# Prediction: [1]. Reality: [1]
# Position: 794 (236/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 148, fps: 25, fns: 24, tns: 104
# Prediction: [0]. Reality: [0]
# Position: 285 (237/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 148, fps: 25, fns: 24, tns: 105
# Prediction: [0]. Reality: [0]
# Position: 818 (238/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 148, fps: 25, fns: 24, tns: 106
# Prediction: [0]. Reality: [0]
# Position: 720 (239/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 148, fps: 26, fns: 24, tns: 106
# Prediction: [1]. Reality: [0]
# Position: 456 (240/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 148, fps: 27, fns: 24, tns: 106
# Prediction: [1]. Reality: [0]
# Position: 193 (241/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 148, fps: 28, fns: 24, tns: 106
# Prediction: [1]. Reality: [0]
# Position: 776 (242/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 148, fps: 29, fns: 24, tns: 106
# Prediction: [1]. Reality: [0]
# Position: 14 (243/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 148, fps: 29, fns: 24, tns: 107
# Prediction: [0]. Reality: [0]
# Position: 499 (244/245)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 148, fps: 29, fns: 24, tns: 108
# Prediction: [0]. Reality: [0]
# Position: 866 (245/245)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 148, fps: 30, fns: 24, tns: 108
# Prediction: [1]. Reality: [0]
# TP: 148, FP: 30, TN: 24, FN: 108
# Results for C:\Users\InbarBlech\PycharmProjects\Thesis\gene:
# Sensitivity (Recall): 0.8604651162790697
# Specificity: 0.782608695652174
# Precision: 0.8314606741573034
# MCC for C:\Users\InbarBlech\PycharmProjects\Thesis\gene: 0.6463498077210456
# Accuracy: 0.8258064516129032

# %%
####### Getting metrics for current protein and adding to metrics_gene_specific_predictors #######

# metrics = pd.DataFrame(columns=["gene", "sensitivity", "specificity", "precision", "accuracy", "mcc", "num_variants", "num_benign", "num_pathogenic"])
# metrics.to_csv("C:\\Users\\InbarBlech\\PycharmProjects\\Thesis\\predictions_vs_real\\gene_specific_predictors\\metrics.csv", index=False)

metrics = pd.read_csv("C:\\Users\\InbarBlech\\PycharmProjects\\Thesis\\predictions_vs_real\\gene_specific_predictors\\metrics_gene_specific_predictors.csv")

protein_metrics = pd.DataFrame({
    "gene": [protein],
    "sensitivity": [sensitivity],
    "specificity": [specificity],
    "precision": [precision],
    "accuracy": [accuracy],
    "mcc": [mcc]
})
protein_metrics["num_variants"] = len(data)
protein_metrics["num_benign"] = sum(data["pathogenicity"] == 0)
protein_metrics["num_pathogenic"] = sum(data["pathogenicity"] == 1)
# add TP, FP, FN, TN to the dataframe
protein_metrics["TP"] = TP
protein_metrics["FP"] = FP
protein_metrics["FN"] = FN
protein_metrics["TN"] = TN
metrics = pd.concat([metrics, protein_metrics], ignore_index=True)
# add the number of variants for each protein
metrics.to_csv("C:\\Users\\InbarBlech\\PycharmProjects\\Thesis\\predictions_vs_real\\gene_specific_predictors\\metrics_gene_specific_predictors.csv", index=False)
