# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, matthews_corrcoef, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
filename = 'C:\\Users\\InbarBlech\\PycharmProjects\\Thesis\\gene_specific_df\\GJB2_combined_with_source_and_position.csv'
data = pd.read_csv(f"{filename}")
data.head(10)
dot_index = filename.index('_')
gene = filename[:dot_index]
if gene == "combined" or gene == "combined_with_source":
    gene = "7 genes"
if gene == "features":
    gene = "190 genes"

data = pd.get_dummies(data, columns=["secondary_structure"])

mapping = {"benign": 0, "pathogenic": 1}
data["pathogenicity"] = data["pathogenicity"].map(mapping)

data = data.drop(
    labels=["source", "uniprot_id", "stability_WT", "stability_MUT", "hydrophobicity_WT", "hydrophobicity_MUT", "volume_WT",
            "volume_MUT", "sequence_length", "oda_MUT", "oda_WT", "sasa_WT", "sasa_MUT", "RSA_MUT", "variant", "gene",
            "protein_contain_transmembrane", "is_residue_transmembranal", "aa_WT", "aa_MUT"], axis=1, inplace=False)

data
# Out:
#      stability_delta  pathogenicity  blosum  hydrophobicity_delta  \
# 0             4.8675              1      -3                  -3.6
# 1            -0.0958              1      -3                   7.0
# 2             2.7659              1      -3                  -8.0
# 3             2.1518              1      -2                  -8.3
# 4            -1.0403              1       0                   2.2
# ..               ...            ...     ...                   ...
# 272          -0.6363              0       0                   2.2
# 273          -0.7241              0      -2                  -3.5
# 274           0.1560              0       2                  -0.6
# 275          -1.0018              0       2                  -0.6
# 276          -0.2300              0       0                  -2.4
#
#      volume_delta  plddt_residue  oda_delta  sasa_delta    RSA_WT   pssm  \
# 0           -54.4          93.72      -0.47        2.03  0.033636  6.426
# 1           -64.9          66.22      -0.11     -106.94  0.712264  4.554
# 2           -52.6          72.33       0.21        3.66  0.022205  4.126
# 3             6.7          92.46      16.80       26.31  0.131414  4.650
# 4            28.5          95.06       2.20       20.58  0.258144  4.448
# ..            ...            ...        ...         ...       ...    ...
# 272          28.5          67.75       4.18       17.56  0.477423  2.786
# 273         108.5          67.75       3.70       81.36  0.477423  2.786
# 274           4.8          58.02       1.52       40.66  0.513261  3.017
# 275           4.8          45.22      -4.47       21.13  0.752957  4.153
# 276         -51.4          31.64       1.22      -54.85  1.264606  2.554
#
#      entropy  position  secondary_structure_Beta strand  \
# 0      0.000        77                                0
# 1      1.874       127                                0
# 2      1.426       121                                0
# 3      0.040        81                                0
# 4      1.984       200                                0
# ..       ...       ...                              ...
# 272    2.657       220                                0
# 273    2.657       220                                0
# 274    2.023       221                                0
# 275    2.317       223                                0
# 276    3.335       226                                0
#
#      secondary_structure_Helix  secondary_structure_Loop  \
# 0                            1                         0
# 1                            0                         1
# 2                            0                         1
# 3                            1                         0
# 4                            1                         0
# ..                         ...                       ...
# 272                          0                         1
# 273                          0                         1
# 274                          0                         1
# 275                          0                         1
# 276                          0                         1
#
#      secondary_structure_Turn
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ..                        ...
# 272                         0
# 273                         0
# 274                         0
# 275                         0
# 276                         0
#
# [277 rows x 16 columns]

# %%
# Drop structural features
data = data.drop(labels=["oda_delta", "stability_delta", "secondary_structure_Beta strand", "secondary_structure_Helix", "secondary_structure_Loop", "sasa_delta", "RSA_WT"], axis=1, inplace=False)

# %%
# Create list of all positions.
positions = data["position"].unique()
tps = []
fps = []
fns = []
tns = []
errors = []
mistakes = 0

counter = 0

for pos in positions:
    counter += 1
    print(f"Position: {pos} ({counter}/{len(positions)})")
    # Create train and test sets.
    train = data[data["position"] != pos]
    test = data[data["position"] == pos]

    X_test = test.drop(labels=["pathogenicity", "position"], axis=1, inplace=False)
    y_test = test["pathogenicity"]

    # Oversamole the train set using SMOTE.
    X_train = train.drop(labels=["pathogenicity", "position"], axis=1, inplace=False)
    y_train = train["pathogenicity"]
    oversample = SMOTE(sampling_strategy='minority', random_state=42)
    X_train_resampled, y_train_resampled = oversample.fit_resample(X_train, y_train)
    # class_distribution = y_train_resampled.value_counts()
    # print(f"Training set: (SMOTE)\n{class_distribution}")

    xgb_classifier = xgb.XGBClassifier(learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42)
    xgb_classifier.fit(X_train_resampled, y_train_resampled)  # Fit the model with the resampled data
    y_pred = xgb_classifier.predict(X_test)

    tp = sum((y_test == 1) & (y_pred == 1))
    fp = sum((y_test == 0) & (y_pred == 1))
    fn = sum((y_test == 1) & (y_pred == 0))
    tn = sum((y_test == 0) & (y_pred == 0))

    print(f"TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}")

    tps.append(tp)
    fps.append(fp)
    fns.append(fn)
    tns.append(tn)

    print(f"tps: {sum(tps)}, fps: {sum(fps)}, fns: {sum(fns)}, tns: {sum(tns)}")

    print(f"Prediction: {y_pred}. Reality: {y_test.values}")
    # # print error if at least one prediction is wrong
    # if not np.array_equal(y_pred, y_test.values):
    #     print(f"Classification is wrong for position {pos}!")
    #     for i in range(len(y_pred)):
    #         if y_pred[i] != y_test.values[i]:
    #             mistakes+=1
    #             print(f"Predicted: {y_pred[i]}, reality: {y_test.values[i]}")

# Calculate MCC
TP = sum(tps)
FP = sum(fps)
FN = sum(fns)
TN = sum(tns)
mcc = (TP * TN - FP * FN) / np.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))

print(f"TP: {sum(tps)}, FP: {sum(fps)}, TN: {sum(fns)}, FN: {sum(tns)}")

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision = TP / (TP + FP)
accuracy = (TP + TN) / (TP + TN + FP + FN)
print(f"Results for {gene}:")
print(f"Sensitivity (Recall): {sensitivity}")
print(f"Specificity: {specificity}")
print(f"Precision: {precision}")
print(f"MCC for {gene}: {mcc}")
print(f"Accuracy: {accuracy}")
# Out:
# Position: 77 (1/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 1, fps: 0, fns: 0, tns: 0
# Prediction: [1]. Reality: [1]
# Position: 127 (2/149)
# TP: 2, FP: 0, TN: 1, FN: 0
# tps: 3, fps: 0, fns: 0, tns: 1
# Prediction: [1 1 0]. Reality: [1 1 0]
# Position: 121 (3/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 4, fps: 0, fns: 0, tns: 1
# Prediction: [1]. Reality: [1]
# Position: 81 (4/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 6, fps: 0, fns: 0, tns: 1
# Prediction: [1 1]. Reality: [1 1]
# Position: 200 (5/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 6, fps: 0, fns: 1, tns: 1
# Prediction: [0]. Reality: [1]
# Position: 46 (6/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 8, fps: 0, fns: 1, tns: 1
# Prediction: [1 1]. Reality: [1 1]
# Position: 45 (7/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 10, fps: 0, fns: 1, tns: 1
# Prediction: [1 1]. Reality: [1 1]
# Position: 82 (8/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 12, fps: 0, fns: 1, tns: 1
# Prediction: [1 1]. Reality: [1 1]
# Position: 151 (9/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 13, fps: 0, fns: 1, tns: 1
# Prediction: [1]. Reality: [1]
# Position: 70 (10/149)
# TP: 4, FP: 0, TN: 0, FN: 0
# tps: 17, fps: 0, fns: 1, tns: 1
# Prediction: [1 1 1 1]. Reality: [1 1 1 1]
# Position: 175 (11/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 19, fps: 0, fns: 1, tns: 1
# Prediction: [1 1]. Reality: [1 1]
# Position: 78 (12/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 21, fps: 0, fns: 1, tns: 1
# Prediction: [1 1]. Reality: [1 1]
# Position: 158 (13/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 22, fps: 0, fns: 1, tns: 1
# Prediction: [1]. Reality: [1]
# Position: 199 (14/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 23, fps: 0, fns: 1, tns: 1
# Prediction: [1]. Reality: [1]
# Position: 32 (15/149)
# TP: 5, FP: 0, TN: 0, FN: 0
# tps: 28, fps: 0, fns: 1, tns: 1
# Prediction: [1 1 1 1 1]. Reality: [1 1 1 1 1]
# Position: 80 (16/149)
# TP: 5, FP: 0, TN: 0, FN: 0
# tps: 33, fps: 0, fns: 1, tns: 1
# Prediction: [1 1 1 1 1]. Reality: [1 1 1 1 1]
# Position: 7 (17/149)
# TP: 0, FP: 0, TN: 1, FN: 1
# tps: 33, fps: 0, fns: 2, tns: 2
# Prediction: [0 0]. Reality: [1 0]
# Position: 20 (18/149)
# TP: 2, FP: 1, TN: 0, FN: 0
# tps: 35, fps: 1, fns: 2, tns: 2
# Prediction: [1 1 1]. Reality: [1 1 0]
# Position: 43 (19/149)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 38, fps: 1, fns: 2, tns: 2
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 44 (20/149)
# TP: 4, FP: 0, TN: 0, FN: 0
# tps: 42, fps: 1, fns: 2, tns: 2
# Prediction: [1 1 1 1]. Reality: [1 1 1 1]
# Position: 31 (21/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 43, fps: 1, fns: 2, tns: 2
# Prediction: [1]. Reality: [1]
# Position: 133 (22/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 45, fps: 1, fns: 2, tns: 2
# Prediction: [1 1]. Reality: [1 1]
# Position: 100 (23/149)
# TP: 2, FP: 0, TN: 0, FN: 1
# tps: 47, fps: 1, fns: 3, tns: 2
# Prediction: [1 0 1]. Reality: [1 1 1]
# Position: 79 (24/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 49, fps: 1, fns: 3, tns: 2
# Prediction: [1 1]. Reality: [1 1]
# Position: 105 (25/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 49, fps: 1, fns: 4, tns: 2
# Prediction: [0]. Reality: [1]
# Position: 54 (26/149)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 52, fps: 1, fns: 4, tns: 2
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 198 (27/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 52, fps: 1, fns: 5, tns: 2
# Prediction: [0]. Reality: [1]
# Position: 130 (28/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 54, fps: 1, fns: 5, tns: 2
# Prediction: [1 1]. Reality: [1 1]
# Position: 38 (29/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 55, fps: 1, fns: 5, tns: 2
# Prediction: [1]. Reality: [1]
# Position: 37 (30/149)
# TP: 1, FP: 0, TN: 0, FN: 1
# tps: 56, fps: 1, fns: 6, tns: 2
# Prediction: [1 0]. Reality: [1 1]
# Position: 66 (31/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 57, fps: 1, fns: 6, tns: 2
# Prediction: [1]. Reality: [1]
# Position: 84 (32/149)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 60, fps: 1, fns: 6, tns: 2
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 15 (33/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 61, fps: 1, fns: 6, tns: 2
# Prediction: [1]. Reality: [1]
# Position: 214 (34/149)
# TP: 1, FP: 0, TN: 1, FN: 0
# tps: 62, fps: 1, fns: 6, tns: 3
# Prediction: [1 0]. Reality: [1 0]
# Position: 120 (35/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 62, fps: 1, fns: 7, tns: 3
# Prediction: [0]. Reality: [1]
# Position: 95 (36/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 63, fps: 1, fns: 7, tns: 3
# Prediction: [1]. Reality: [1]
# Position: 59 (37/149)
# TP: 4, FP: 0, TN: 0, FN: 0
# tps: 67, fps: 1, fns: 7, tns: 3
# Prediction: [1 1 1 1]. Reality: [1 1 1 1]
# Position: 184 (38/149)
# TP: 4, FP: 0, TN: 0, FN: 0
# tps: 71, fps: 1, fns: 7, tns: 3
# Prediction: [1 1 1 1]. Reality: [1 1 1 1]
# Position: 53 (39/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 73, fps: 1, fns: 7, tns: 3
# Prediction: [1 1]. Reality: [1 1]
# Position: 142 (40/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 74, fps: 1, fns: 7, tns: 3
# Prediction: [1]. Reality: [1]
# Position: 52 (41/149)
# TP: 0, FP: 0, TN: 2, FN: 1
# tps: 74, fps: 1, fns: 8, tns: 5
# Prediction: [0 0 0]. Reality: [1 0 0]
# Position: 13 (42/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 75, fps: 1, fns: 8, tns: 5
# Prediction: [1]. Reality: [1]
# Position: 203 (43/149)
# TP: 1, FP: 0, TN: 1, FN: 0
# tps: 76, fps: 1, fns: 8, tns: 6
# Prediction: [1 0]. Reality: [1 0]
# Position: 47 (44/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 78, fps: 1, fns: 8, tns: 6
# Prediction: [1 1]. Reality: [1 1]
# Position: 109 (45/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 79, fps: 1, fns: 8, tns: 6
# Prediction: [1]. Reality: [1]
# Position: 190 (46/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 80, fps: 1, fns: 8, tns: 6
# Prediction: [1]. Reality: [1]
# Position: 122 (47/149)
# TP: 1, FP: 0, TN: 1, FN: 0
# tps: 81, fps: 1, fns: 8, tns: 7
# Prediction: [1 0]. Reality: [1 0]
# Position: 17 (48/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 83, fps: 1, fns: 8, tns: 7
# Prediction: [1 1]. Reality: [1 1]
# Position: 205 (49/149)
# TP: 2, FP: 1, TN: 0, FN: 0
# tps: 85, fps: 2, fns: 8, tns: 7
# Prediction: [1 1 1]. Reality: [1 1 0]
# Position: 132 (50/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 86, fps: 2, fns: 8, tns: 7
# Prediction: [1]. Reality: [1]
# Position: 40 (51/149)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 89, fps: 2, fns: 8, tns: 7
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 14 (52/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 91, fps: 2, fns: 8, tns: 7
# Prediction: [1 1]. Reality: [1 1]
# Position: 8 (53/149)
# TP: 0, FP: 1, TN: 1, FN: 1
# tps: 91, fps: 3, fns: 9, tns: 8
# Prediction: [0 1 0]. Reality: [1 0 0]
# Position: 63 (54/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 92, fps: 3, fns: 9, tns: 8
# Prediction: [1]. Reality: [1]
# Position: 72 (55/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 93, fps: 3, fns: 9, tns: 8
# Prediction: [1]. Reality: [1]
# Position: 50 (56/149)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 96, fps: 3, fns: 9, tns: 8
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 140 (57/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 97, fps: 3, fns: 9, tns: 8
# Prediction: [1]. Reality: [1]
# Position: 12 (58/149)
# TP: 4, FP: 0, TN: 0, FN: 0
# tps: 101, fps: 3, fns: 9, tns: 8
# Prediction: [1 1 1 1]. Reality: [1 1 1 1]
# Position: 128 (59/149)
# TP: 1, FP: 0, TN: 0, FN: 1
# tps: 102, fps: 3, fns: 10, tns: 8
# Prediction: [1 0]. Reality: [1 1]
# Position: 206 (60/149)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 105, fps: 3, fns: 10, tns: 8
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 112 (61/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 105, fps: 3, fns: 11, tns: 8
# Prediction: [0]. Reality: [1]
# Position: 73 (62/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 107, fps: 3, fns: 11, tns: 8
# Prediction: [1 1]. Reality: [1 1]
# Position: 11 (63/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 108, fps: 3, fns: 11, tns: 8
# Prediction: [1]. Reality: [1]
# Position: 163 (64/149)
# TP: 1, FP: 0, TN: 0, FN: 1
# tps: 109, fps: 3, fns: 12, tns: 8
# Prediction: [1 0]. Reality: [1 1]
# Position: 90 (65/149)
# TP: 2, FP: 0, TN: 0, FN: 1
# tps: 111, fps: 3, fns: 13, tns: 8
# Prediction: [1 1 0]. Reality: [1 1 1]
# Position: 88 (66/149)
# TP: 4, FP: 0, TN: 0, FN: 0
# tps: 115, fps: 3, fns: 13, tns: 8
# Prediction: [1 1 1 1]. Reality: [1 1 1 1]
# Position: 226 (67/149)
# TP: 2, FP: 0, TN: 1, FN: 0
# tps: 117, fps: 3, fns: 13, tns: 9
# Prediction: [1 1 0]. Reality: [1 1 0]
# Position: 34 (68/149)
# TP: 5, FP: 0, TN: 0, FN: 0
# tps: 122, fps: 3, fns: 13, tns: 9
# Prediction: [1 1 1 1 1]. Reality: [1 1 1 1 1]
# Position: 186 (69/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 124, fps: 3, fns: 13, tns: 9
# Prediction: [1 1]. Reality: [1 1]
# Position: 202 (70/149)
# TP: 2, FP: 1, TN: 0, FN: 0
# tps: 126, fps: 4, fns: 13, tns: 9
# Prediction: [1 1 1]. Reality: [1 1 0]
# Position: 139 (71/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 128, fps: 4, fns: 13, tns: 9
# Prediction: [1 1]. Reality: [1 1]
# Position: 64 (72/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 129, fps: 4, fns: 13, tns: 9
# Prediction: [1]. Reality: [1]
# Position: 71 (73/149)
# TP: 1, FP: 0, TN: 1, FN: 0
# tps: 130, fps: 4, fns: 13, tns: 10
# Prediction: [1 0]. Reality: [1 0]
# Position: 176 (74/149)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 131, fps: 5, fns: 13, tns: 10
# Prediction: [1 1]. Reality: [1 0]
# Position: 114 (75/149)
# TP: 0, FP: 1, TN: 0, FN: 1
# tps: 131, fps: 6, fns: 14, tns: 10
# Prediction: [0 1]. Reality: [1 0]
# Position: 113 (76/149)
# TP: 0, FP: 0, TN: 2, FN: 1
# tps: 131, fps: 6, fns: 15, tns: 12
# Prediction: [0 0 0]. Reality: [1 0 0]
# Position: 93 (77/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 132, fps: 6, fns: 15, tns: 12
# Prediction: [1]. Reality: [1]
# Position: 89 (78/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 133, fps: 6, fns: 15, tns: 12
# Prediction: [1]. Reality: [1]
# Position: 183 (79/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 134, fps: 6, fns: 15, tns: 12
# Prediction: [1]. Reality: [1]
# Position: 218 (80/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 135, fps: 6, fns: 15, tns: 12
# Prediction: [1]. Reality: [1]
# Position: 30 (81/149)
# TP: 1, FP: 0, TN: 1, FN: 1
# tps: 136, fps: 6, fns: 16, tns: 13
# Prediction: [1 0 0]. Reality: [1 1 0]
# Position: 143 (82/149)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 139, fps: 6, fns: 16, tns: 13
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 55 (83/149)
# TP: 3, FP: 0, TN: 0, FN: 0
# tps: 142, fps: 6, fns: 16, tns: 13
# Prediction: [1 1 1]. Reality: [1 1 1]
# Position: 56 (84/149)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 143, fps: 7, fns: 16, tns: 13
# Prediction: [1 1]. Reality: [1 0]
# Position: 197 (85/149)
# TP: 0, FP: 0, TN: 1, FN: 1
# tps: 143, fps: 7, fns: 17, tns: 14
# Prediction: [0 0]. Reality: [1 0]
# Position: 61 (86/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 143, fps: 7, fns: 18, tns: 14
# Prediction: [0]. Reality: [1]
# Position: 98 (87/149)
# TP: 2, FP: 1, TN: 3, FN: 1
# tps: 145, fps: 8, fns: 19, tns: 17
# Prediction: [0 1 1 0 0 1 0]. Reality: [1 1 1 0 0 0 0]
# Position: 85 (88/149)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 146, fps: 9, fns: 19, tns: 17
# Prediction: [1 1]. Reality: [1 0]
# Position: 86 (89/149)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 147, fps: 10, fns: 19, tns: 17
# Prediction: [1 1]. Reality: [1 0]
# Position: 22 (90/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 147, fps: 10, fns: 20, tns: 17
# Prediction: [0]. Reality: [1]
# Position: 58 (91/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 149, fps: 10, fns: 20, tns: 17
# Prediction: [1 1]. Reality: [1 1]
# Position: 75 (92/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 151, fps: 10, fns: 20, tns: 17
# Prediction: [1 1]. Reality: [1 1]
# Position: 119 (93/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 152, fps: 10, fns: 20, tns: 17
# Prediction: [1]. Reality: [1]
# Position: 115 (94/149)
# TP: 0, FP: 0, TN: 1, FN: 1
# tps: 152, fps: 10, fns: 21, tns: 18
# Prediction: [0 0]. Reality: [1 0]
# Position: 33 (95/149)
# TP: 1, FP: 0, TN: 1, FN: 0
# tps: 153, fps: 10, fns: 21, tns: 19
# Prediction: [1 0]. Reality: [1 0]
# Position: 18 (96/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 154, fps: 10, fns: 21, tns: 19
# Prediction: [1]. Reality: [1]
# Position: 16 (97/149)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 155, fps: 11, fns: 21, tns: 19
# Prediction: [1 1]. Reality: [1 0]
# Position: 42 (98/149)
# TP: 0, FP: 0, TN: 0, FN: 2
# tps: 155, fps: 11, fns: 23, tns: 19
# Prediction: [0 0]. Reality: [1 1]
# Position: 10 (99/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 157, fps: 11, fns: 23, tns: 19
# Prediction: [1 1]. Reality: [1 1]
# Position: 225 (100/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 158, fps: 11, fns: 23, tns: 19
# Prediction: [1]. Reality: [1]
# Position: 6 (101/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 159, fps: 11, fns: 23, tns: 19
# Prediction: [1]. Reality: [1]
# Position: 169 (102/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 160, fps: 11, fns: 23, tns: 19
# Prediction: [1]. Reality: [1]
# Position: 60 (103/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 161, fps: 11, fns: 23, tns: 19
# Prediction: [1]. Reality: [1]
# Position: 101 (104/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 162, fps: 11, fns: 23, tns: 19
# Prediction: [1]. Reality: [1]
# Position: 36 (105/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 163, fps: 11, fns: 23, tns: 19
# Prediction: [1]. Reality: [1]
# Position: 172 (106/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 165, fps: 11, fns: 23, tns: 19
# Prediction: [1 1]. Reality: [1 1]
# Position: 159 (107/149)
# TP: 1, FP: 0, TN: 1, FN: 0
# tps: 166, fps: 11, fns: 23, tns: 20
# Prediction: [1 0]. Reality: [1 0]
# Position: 19 (108/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 166, fps: 11, fns: 24, tns: 20
# Prediction: [0]. Reality: [1]
# Position: 173 (109/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 167, fps: 11, fns: 24, tns: 20
# Prediction: [1]. Reality: [1]
# Position: 174 (110/149)
# TP: 2, FP: 0, TN: 0, FN: 0
# tps: 169, fps: 11, fns: 24, tns: 20
# Prediction: [1 1]. Reality: [1 1]
# Position: 147 (111/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 170, fps: 11, fns: 24, tns: 20
# Prediction: [1]. Reality: [1]
# Position: 161 (112/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 171, fps: 11, fns: 24, tns: 20
# Prediction: [1]. Reality: [1]
# Position: 208 (113/149)
# TP: 0, FP: 0, TN: 0, FN: 1
# tps: 171, fps: 11, fns: 25, tns: 20
# Prediction: [0]. Reality: [1]
# Position: 134 (114/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 172, fps: 11, fns: 25, tns: 20
# Prediction: [1]. Reality: [1]
# Position: 153 (115/149)
# TP: 0, FP: 0, TN: 1, FN: 1
# tps: 172, fps: 11, fns: 26, tns: 21
# Prediction: [0 0]. Reality: [1 0]
# Position: 178 (116/149)
# TP: 1, FP: 1, TN: 0, FN: 0
# tps: 173, fps: 12, fns: 26, tns: 21
# Prediction: [1 1]. Reality: [1 0]
# Position: 35 (117/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 174, fps: 12, fns: 26, tns: 21
# Prediction: [1]. Reality: [1]
# Position: 138 (118/149)
# TP: 0, FP: 0, TN: 1, FN: 1
# tps: 174, fps: 12, fns: 27, tns: 22
# Prediction: [0 0]. Reality: [1 0]
# Position: 111 (119/149)
# TP: 0, FP: 0, TN: 2, FN: 1
# tps: 174, fps: 12, fns: 28, tns: 24
# Prediction: [0 0 0]. Reality: [1 0 0]
# Position: 24 (120/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 175, fps: 12, fns: 28, tns: 24
# Prediction: [1]. Reality: [1]
# Position: 179 (121/149)
# TP: 1, FP: 0, TN: 0, FN: 0
# tps: 176, fps: 12, fns: 28, tns: 24
# Prediction: [1]. Reality: [1]
# Position: 27 (122/149)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 176, fps: 13, fns: 28, tns: 24
# Prediction: [1]. Reality: [0]
# Position: 4 (123/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 13, fns: 28, tns: 25
# Prediction: [0]. Reality: [0]
# Position: 5 (124/149)
# TP: 0, FP: 1, TN: 1, FN: 0
# tps: 176, fps: 14, fns: 28, tns: 26
# Prediction: [0 1]. Reality: [0 0]
# Position: 28 (125/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 14, fns: 28, tns: 27
# Prediction: [0]. Reality: [0]
# Position: 68 (126/149)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 176, fps: 14, fns: 28, tns: 29
# Prediction: [0 0]. Reality: [0 0]
# Position: 97 (127/149)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 176, fps: 15, fns: 28, tns: 29
# Prediction: [1]. Reality: [0]
# Position: 102 (128/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 15, fns: 28, tns: 30
# Prediction: [0]. Reality: [0]
# Position: 107 (129/149)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 176, fps: 15, fns: 28, tns: 32
# Prediction: [0 0]. Reality: [0 0]
# Position: 108 (130/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 15, fns: 28, tns: 33
# Prediction: [0]. Reality: [0]
# Position: 117 (131/149)
# TP: 0, FP: 1, TN: 0, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 33
# Prediction: [1]. Reality: [0]
# Position: 118 (132/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 34
# Prediction: [0]. Reality: [0]
# Position: 123 (133/149)
# TP: 0, FP: 0, TN: 3, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 37
# Prediction: [0 0 0]. Reality: [0 0 0]
# Position: 126 (134/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 38
# Prediction: [0]. Reality: [0]
# Position: 131 (135/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 39
# Prediction: [0]. Reality: [0]
# Position: 144 (136/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 40
# Prediction: [0]. Reality: [0]
# Position: 145 (137/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 41
# Prediction: [0]. Reality: [0]
# Position: 149 (138/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 42
# Prediction: [0]. Reality: [0]
# Position: 156 (139/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 43
# Prediction: [0]. Reality: [0]
# Position: 162 (140/149)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 45
# Prediction: [0 0]. Reality: [0 0]
# Position: 164 (141/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 16, fns: 28, tns: 46
# Prediction: [0]. Reality: [0]
# Position: 170 (142/149)
# TP: 0, FP: 1, TN: 2, FN: 0
# tps: 176, fps: 17, fns: 28, tns: 48
# Prediction: [1 0 0]. Reality: [0 0 0]
# Position: 182 (143/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 17, fns: 28, tns: 49
# Prediction: [0]. Reality: [0]
# Position: 196 (144/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 17, fns: 28, tns: 50
# Prediction: [0]. Reality: [0]
# Position: 207 (145/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 17, fns: 28, tns: 51
# Prediction: [0]. Reality: [0]
# Position: 217 (146/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 17, fns: 28, tns: 52
# Prediction: [0]. Reality: [0]
# Position: 220 (147/149)
# TP: 0, FP: 0, TN: 2, FN: 0
# tps: 176, fps: 17, fns: 28, tns: 54
# Prediction: [0 0]. Reality: [0 0]
# Position: 221 (148/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 17, fns: 28, tns: 55
# Prediction: [0]. Reality: [0]
# Position: 223 (149/149)
# TP: 0, FP: 0, TN: 1, FN: 0
# tps: 176, fps: 17, fns: 28, tns: 56
# Prediction: [0]. Reality: [0]
# TP: 176, FP: 17, TN: 28, FN: 56
# Results for C:\Users\InbarBlech\PycharmProjects\Thesis\gene:
# Sensitivity (Recall): 0.8627450980392157
# Specificity: 0.7671232876712328
# Precision: 0.9119170984455959
# MCC for C:\Users\InbarBlech\PycharmProjects\Thesis\gene: 0.6036817225405571
# Accuracy: 0.8375451263537906

# %%
# # # Access feature importances
# feature_importances = xgb_classifier.feature_importances_
# 
# # Calculate the confusion matrix
# conf_matrix = confusion_matrix(y_test, y_pred)
# 
# # Get the sensitivity, specificity, FPV and TPV values
# conf_matrix[1, 1] = TP
# conf_matrix[1, 0] = FN
# conf_matrix[0, 0] = TN
# conf_matrix[0, 1] = FP
# 
# # Create a heatmap for visualization
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
# plt.xlabel('Predicted Labels')
# plt.ylabel('True Labels')
# plt.title(f'Confusion Matrix for {gene}')
# plt.show()
