# %%
import matplotlib.pyplot as plt

# %%
model_performance_dict = {'MYO7A': {}, 'FGFR1': {}, 'SLC26A4': {}, 'WFS1': {}, 'COL4A5': {}, 'COL2A1': {}, 'COL4A3': {}, 'GJB2': {}}

model_performance_dict['MYO7A']['regular'] = 0.563
model_performance_dict['MYO7A']['oda_delta'] = 0.548
model_performance_dict['MYO7A']['stability_delta'] = 0.525
model_performance_dict['MYO7A']['entropy'] = 0.495
model_performance_dict['MYO7A']['plddt_residue'] = 0.553
model_performance_dict['MYO7A']['sasa_delta'] = 0.548
model_performance_dict['MYO7A']['RSA_WT'] = 0.546
model_performance_dict['MYO7A']['pssm'] = 0.557
model_performance_dict['MYO7A']['hydrophobicity_delta'] = 0.559
model_performance_dict['MYO7A']['blosum'] = 0.551
model_performance_dict['MYO7A']['volume_delta'] = 0.534
model_performance_dict['MYO7A']['secondary_structure'] = 0.518

model_performance_dict['FGFR1']['regular'] = 0.609
model_performance_dict['FGFR1']['oda_delta'] = 0.665
model_performance_dict['FGFR1']['stability_delta'] = 0.599
model_performance_dict['FGFR1']['entropy'] = 0.531
model_performance_dict['FGFR1']['plddt_residue'] = 0.667
model_performance_dict['FGFR1']['sasa_delta'] = 0.613
model_performance_dict['FGFR1']['RSA_WT'] = 0.613
model_performance_dict['FGFR1']['pssm'] = 0.639
model_performance_dict['FGFR1']['hydrophobicity_delta'] = 0.645
model_performance_dict['FGFR1']['blosum'] = 0.633
model_performance_dict['FGFR1']['volume_delta'] = 0.625
model_performance_dict['FGFR1']['secondary_structure'] = 0.618

model_performance_dict['SLC26A4']['regular'] = 0.53
model_performance_dict['SLC26A4']['oda_delta'] = 0.569
model_performance_dict['SLC26A4']['stability_delta'] = 0.52
model_performance_dict['SLC26A4']['entropy'] = 0.54
model_performance_dict['SLC26A4']['plddt_residue'] = 0.54
model_performance_dict['SLC26A4']['sasa_delta'] = 0.604
model_performance_dict['SLC26A4']['RSA_WT'] = 0.569
model_performance_dict['SLC26A4']['pssm'] = 0.511
model_performance_dict['SLC26A4']['hydrophobicity_delta'] = 0.525
model_performance_dict['SLC26A4']['blosum'] = 0.535
model_performance_dict['SLC26A4']['volume_delta'] = 0.545
model_performance_dict['SLC26A4']['secondary_structure'] = 0.53

model_performance_dict['WFS1']['regular'] = 0.647
model_performance_dict['WFS1']['oda_delta'] = 0.666
model_performance_dict['WFS1']['stability_delta'] = 0.646
model_performance_dict['WFS1']['entropy'] = 0.646
model_performance_dict['WFS1']['plddt_residue'] = 0.725
model_performance_dict['WFS1']['sasa_delta'] = 0.666
model_performance_dict['WFS1']['RSA_WT'] = 0.627
model_performance_dict['WFS1']['pssm'] = 0.633
model_performance_dict['WFS1']['hydrophobicity_delta'] = 0.659
model_performance_dict['WFS1']['blosum'] = 0.62
model_performance_dict['WFS1']['volume_delta'] = 0.647
model_performance_dict['WFS1']['secondary_structure'] = 0.647

model_performance_dict['COL4A5']['regular'] = 0.908
model_performance_dict['COL4A5']['oda_delta'] = 0.908
model_performance_dict['COL4A5']['stability_delta'] = 0.915
model_performance_dict['COL4A5']['entropy'] = 0.899
model_performance_dict['COL4A5']['plddt_residue'] = 0.909
model_performance_dict['COL4A5']['sasa_delta'] = 0.923
model_performance_dict['COL4A5']['RSA_WT'] = 0.922
model_performance_dict['COL4A5']['pssm'] = 0.915
model_performance_dict['COL4A5']['hydrophobicity_delta'] = 0.912
model_performance_dict['COL4A5']['blosum'] = 0.919
model_performance_dict['COL4A5']['volume_delta'] = 0.918
model_performance_dict['COL4A5']['secondary_structure'] = 0.909

model_performance_dict['COL2A1']['regular'] = 0.865
model_performance_dict['COL2A1']['oda_delta'] = 0.866
model_performance_dict['COL2A1']['stability_delta'] = 0.856
model_performance_dict['COL2A1']['entropy'] = 0.855
model_performance_dict['COL2A1']['plddt_residue'] = 0.863
model_performance_dict['COL2A1']['sasa_delta'] = 0.863
model_performance_dict['COL2A1']['RSA_WT'] = 0.872
model_performance_dict['COL2A1']['pssm'] = 0.858
model_performance_dict['COL2A1']['hydrophobicity_delta'] = 0.863
model_performance_dict['COL2A1']['blosum'] = 0.86
model_performance_dict['COL2A1']['volume_delta'] = 0.857
model_performance_dict['COL2A1']['secondary_structure'] = 0.865

model_performance_dict['COL4A3']['regular'] = 0.8
model_performance_dict['COL4A3']['oda_delta'] = 0.794
model_performance_dict['COL4A3']['stability_delta'] = 0.806
model_performance_dict['COL4A3']['entropy'] = 0.718
model_performance_dict['COL4A3']['plddt_residue'] = 0.794
model_performance_dict['COL4A3']['sasa_delta'] = 0.818
model_performance_dict['COL4A3']['RSA_WT'] = 0.788
model_performance_dict['COL4A3']['pssm'] = 0.782
model_performance_dict['COL4A3']['hydrophobicity_delta'] = 0.794
model_performance_dict['COL4A3']['blosum'] = 0.799
model_performance_dict['COL4A3']['volume_delta'] = 0.802
model_performance_dict['COL4A3']['secondary_structure'] = 0.782

model_performance_dict['GJB2']['regular'] = 0.566
model_performance_dict['GJB2']['oda_delta'] = 0.563
model_performance_dict['GJB2']['stability_delta'] = 0.585
model_performance_dict['GJB2']['entropy'] = 0.506
model_performance_dict['GJB2']['plddt_residue'] = 0.550
model_performance_dict['GJB2']['sasa_delta'] = 0.546
model_performance_dict['GJB2']['RSA_WT'] = 0.570
model_performance_dict['GJB2']['pssm'] = 0.556
model_performance_dict['GJB2']['hydrophobicity_delta'] = 0.541
model_performance_dict['GJB2']['blosum'] = 0.516
model_performance_dict['GJB2']['volume_delta'] = 0.568
model_performance_dict['GJB2']['secondary_structure'] = 0.552

# %%
for model in model_performance_dict:
    features = list(model_performance_dict[model].keys())
    regular_performance = model_performance_dict[model]['regular']
    performance_changes = {feature: regular_performance - model_performance_dict[model][feature] for feature in features}
    
    # Create a bar chart for feature importance changes
    fig, ax = plt.subplots()
    bars = ax.bar(features, performance_changes.values(), label=f'Model: {model}')
    
    plt.xlabel('Feature')
    plt.ylabel('MCC Performance Change')
    plt.title(f'Feature Importance - Model: {model}')
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    
    # Add a side panel with MCC values
    side_panel_text = '\n'.join([f'{feature}: {model_performance_dict[model][feature]:.3f}' for feature in features])
    fig.text(1.1, 0.5, side_panel_text, va='center', ha='left', fontsize=10)
    
    plt.show()
